# %% [markdown]
# <a href="https://colab.research.google.com/github/binteaamer/FlyrankInternship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/binteaamer/FlyrankInternship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
# !git clone https://github.com/binteaamer/FlyrankInternship.git
# %cd FlyrankInternship
# Out:
# Cloning into 'FlyrankInternship'...
# remote: Enumerating objects: 142, done.
# remote: Counting objects: 100% (142/142), done.
# remote: Compressing objects: 100% (98/98), done.
# remote: Total 142 (delta 52), reused 92 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (142/142), 1.85 MiB | 13.54 MiB/s, done.
# Resolving deltas: 100% (52/52), done.
# /content/FlyrankInternship

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Shape:", df.shape)

print("\nColumns:")
print(df.columns.tolist())

print("\nData types:")
print(df.dtypes)

print("\nMissing values:")
print(df.isna().sum().sort_values(ascending=False).head(20))
# Out:
# Shape: (30000, 44)
#
# Columns:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']
#
# Data types:
# content_id                 object
# client_id                  object
# search_volume             float64
# competition               float64
# ...

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# Freestyle — CTR Opportunity
#
# I want to investigate whether some pages receive fewer clicks than expected given their search visibility and other relevant page-level characteristics. The goal is to identify pages that may be worth reviewing for possible CTR improvement. I chose this as a freestyle question because the starter dataset contains page-level CTR, search position, impressions, and other SEO signals, while the existing starter project focuses on identifying declining pages for content refresh. This makes CTR opportunity a related but different decision problem.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
#
# **Decision**
#
# Which pages should be prioritised for review because they may have an opportunity to improve their click-through rate?
#
# **Who acts?**
#
# An SEO specialist or content editor reviews the prioritised pages and decides whether an optimisation is appropriate. Possible actions could include reviewing the page title, meta description, search-intent alignment, or other page elements that may affect clicks.
#
# **Cost of a wrong recommendation**
#
# Prioritising the wrong pages could waste SEO and content resources on pages with little opportunity for improvement. Missing a page with a genuine CTR opportunity could also mean losing potential clicks that the page could have received from its existing search visibility.
#
# **Why data helps**
#
# The dataset contains 30,000 page-level observations and multiple SEO signals, including CTR, average search position, impressions, search volume, content age, and engagement measures. Looking at these signals together may help identify pages that are more likely to have a meaningful CTR opportunity than using a simple low-CTR rule.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# The starter dataset contains 30,000 pages. I used the available CTR and search-position data to check whether there is enough variation to make a CTR-opportunity question worth investigating.
#
# The overall correlation between average search position and CTR is -0.073. This is a weak negative linear relationship, so average position alone does not explain most of the variation in CTR.
#
# However, the position tiers show more noticeable differences in average CTR. For example, the average CTR is 0.334 for pages in the top 3 positions, compared with 0.055 for pages in the deep position tier.
#
# These results suggest that CTR should not be judged using one overall threshold. A page's search position and other available page-level characteristics may need to be considered when identifying potential CTR opportunities.taset.

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Total pages:", len(df))

corr = df["avg_position"].corr(df["ctr"])
print(f"Correlation between avg_position and CTR: {corr:.3f}")

print("\nAverage CTR:", round(df["ctr"].mean(),3))
print("Average search position:", round(df["avg_position"].mean(),2))

visible = df[df["impressions_90d"] >= 100]

print("\nAverage CTR by position tier:")
print(
    visible.groupby("position_tier")["ctr"]
    .mean()
    .round(3)
)
# Out:
# Total pages: 30000
# Correlation between avg_position and CTR: -0.073
#
# Average CTR: 0.511
# Average search position: 16.34
#
# Average CTR by position tier:
# position_tier
# deep        0.055
# page_1      0.355
# page_3_5    0.142
# striking    0.256
# top_3       0.334
# Name: ctr, dtype: float64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# ## Careful words
#
# This project will measure observed patterns in CTR and other available page-level SEO signals. The goal is to provide decision support for prioritising pages that may have a CTR opportunity.
#
# The current data shows differences in CTR across search-position groups, but these observations do not prove that search position causes changes in CTR. The overall correlation between average search position and CTR is also weak.
#
# The project will not claim to predict or explain Google's ranking algorithm. It will not prove that changing a page's title, meta description, or content will cause CTR to increase.
#
# Any final findings will be described as observed patterns or predictive/decision-support results based on the available dataset. If a model is used, its performance will be evaluated against an appropriate baseline rather than assuming that a model is useful simply because it produces predictions.

# %% [markdown]
# The observed correlation between average search position and CTR was -0.073, indicating a weak negative relationship. Average search position alone does not strongly explain differences in CTR.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
